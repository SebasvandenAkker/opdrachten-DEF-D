# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 13           |  Student Studienummer
# | :-------------------|:-------------|
# | Sebas van den Akker | 6562892      |
# | Xin Qi Huang        | 6345735      |
# | Abel van Oord       | 6580920      |
#
# | Planning Groep: 13                         |Tijdstip / Tijdspanne  |
# |--------------------------------------------|-----------------------|
# | Mijlpaal 1: Github pull requests           | 11:00  |
# | Mijlpaal 2: Sensoren aansluiten            | 11:15  |
# | Mijlpaal 3: Ideen voor de sensoren         | 11:30  |
# | Mijlpaal 4: Criteria opgesteld             | 12:00  |
# | Pauze 1                                    | 12:45-13:45 |
# | Mijlpaal 5: Eerste kalibratie meting gedaan| 14:30  |
# | Mijlpaal 6: simulatie                      | 15:00  |
# | Mijlpaal 7: conclusie en leerdoelen af     | 16:00  |
# | Mijlpaal 8: werk inleveren                 | 16:30  |
# | Mijlpaal 9: feedback geven en inleveren    | 17:00  |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](IMG_9684.jpg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---                  |:---|:---|
# | druksensor           | precisieweegschaal        | tussen de 0 en 1000 gram op 5 gram nauwkeurig. de volledige massa moet alleen kracht leveren op het meet oppervlak van de sensor. |
# | temperatuur weerstand| waterkoker schakelaar |  meten of iets warmer dan 99 graden celsius met een nauwkeurigheid van 1 graad. moet waterbestendig zijn IPx8.|
# | licht weerstand      | lichtgevoelige lichtschakelaar (lantaarnpaal voetpad) | moet onderscheid kunnen maken tussen omgevings licht van onder de 700 lux en boven de 1300 lux met marge van 50 marge. waterbestendig tegen regen IPx5. de sensor moet niet aangaan door de lantaarnpaal bij snelweg van 100 lux die aan wordt gezet.|
#
#
# Groep 13 heeft gekozen voor sensor licht weerstand.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# de meetopstelling
#  ![Alt]( IMG_9685.jpg "schets student")
#
# opstelling circuit
#  ![Alt]( IMG_9687.jpg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen? afstand tot de lichtbron en daarmee de lux
# 2. Over welk bereik ga je deze variabelen veranderen? afstand van 10 tot 24 cm
# 3. Wat ga je allemaal meten? de lichtintensiteit in lux
# 4. Hoeveel metingen ga je doen? 7 in intervallen van 2 cm
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen? ja

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
# Dit is de meetopstelling terwijl we de data voor de sensor aan het verzamelen waren. voor de echte meetwaarden deden we de doos dicht. hierna is het zelfde gedaan met de lux sensor op een telefoon op de zelfde afstanden.
#
#  ![Alt](opstelling.JPG "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
telefoon = np.array([1318,943,763,672,527,450,381])
sensor = np.array([289,250,207,183,169,149,130])

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
plt.scatter(telefoon, sensor)
plt.errorbar(telefoon, sensor, 10, 40, "*")
plt.xlabel("Telefoon metingen lux")
plt.ylabel("Sensor metingen bits")

def f(telefoon, a, b):
    return a*telefoon + b

val, cov = curve_fit(f, telefoon, sensor)
x_fit = np.linspace(min(telefoon), max(telefoon), 100)
y_fit = f(x_fit, val[0], val[1])
plt.plot(x_fit,y_fit)

print(val)
# Out:
# [ 0.17126976 73.0575166 ]

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# We gaan niet itereren.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
# Uit onze metingen blijkt een duidelijk lineair verband tussen lux en de sensorwaarde. Rond de 700 lux is een goed verschil terug te zien. Echter is er een minder goed verschil terug te zien rond de 1300. De onzekerheid is 40 wat kleiner is dan de marge van 50 waardoor de sensor dus gebruikt kan worden voor het doel. Om te checken of de sensor een ipx5 waarde heeft is er vervolg onderzoek nodig.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
# Dit is de meetopstelling terwijl we de data voor de sensor aan het verzamelen waren. voor de echte meetwaarden deden we de doos dicht. hierna is het zelfde gedaan met de lux sensor op een telefoon op de zelfde afstanden.
#
#  ![Alt](opstelling.JPG "meetopstelling student")

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# de meetopstelling
#  ![Alt]( IMG_9685.jpg "schets student")
#
# opstelling circuit
#  ![Alt]( IMG_9687.jpg "schets student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---                  |:---|:---|
# | druksensor           | precisieweegschaal        | tussen de 0 en 1000 gram op 5 gram nauwkeurig. de volledige massa moet alleen kracht leveren op het meet oppervlak van de sensor. |
# | temperatuur weerstand| waterkoker schakelaar |  meten of iets warmer dan 99 graden celsius met een nauwkeurigheid van 1 graad. moet waterbestendig zijn IPx8.|
# | licht weerstand      | lichtgevoelige lichtschakelaar (lantaarnpaal voetpad) | moet onderscheid kunnen maken tussen omgevings licht van onder de 700 lux en boven de 1300 lux met marge van 50 marge. waterbestendig tegen regen IPx5. de sensor moet niet aangaan door de lantaarnpaal bij snelweg van 100 lux die aan wordt gezet.|
#
#
# Groep 13 heeft gekozen voor sensor licht weerstand.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# de meetopstelling
#  ![Alt]( IMG_9685.jpg "schets student")
#
# opstelling circuit
#  ![Alt]( IMG_9687.jpg "schets student")

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
# Dit is de meetopstelling terwijl we de data voor de sensor aan het verzamelen waren. voor de echte meetwaarden deden we de doos dicht. hierna is het zelfde gedaan met de lux sensor op een telefoon op de zelfde afstanden.
#
#  ![Alt](opstelling.JPG "meetopstelling student")

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
telefoon = np.array([1318,943,763,672,527,450,381])
sensor = np.array([289,250,207,183,169,149,130])

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
plt.scatter(telefoon, sensor)
plt.errorbar(telefoon, sensor, 10, 40, "*")
plt.xlabel("Telefoon metingen lux")
plt.ylabel("Sensor metingen bits")

def f(telefoon, a, b):
    return a*telefoon + b

val, cov = curve_fit(f, telefoon, sensor)
x_fit = np.linspace(min(telefoon), max(telefoon), 100)
y_fit = f(x_fit, val[0], val[1])
plt.plot(x_fit,y_fit)

print(val)
# Out:
# [ 0.17126976 73.0575166 ]

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
# Uit onze metingen blijkt een duidelijk lineair verband tussen lux en de sensorwaarde. Rond de 700 lux is een goed verschil terug te zien. Echter is er een minder goed verschil terug te zien rond de 1300. De onzekerheid is 40 wat kleiner is dan de marge van 50 waardoor de sensor dus gebruikt kan worden voor het doel. Om te checken of de sensor een ipx5 waarde heeft is er vervolg onderzoek nodig.
